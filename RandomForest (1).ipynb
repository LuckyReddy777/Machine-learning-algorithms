# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('horse.csv')

# %%
data.head()
# Out:
#   surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0      no  adult           530101         38.5   66.0              28.0
# 1     yes  adult           534817         39.2   88.0              20.0
# 2      no  adult           530334         38.3   40.0              24.0
# 3     yes  young          5290409         39.1  164.0              84.0
# 4      no  adult           530255         37.3  104.0              35.0
#
#   temp_of_extremities peripheral_pulse mucous_membrane capillary_refill_time  \
# 0                cool          reduced             NaN            more_3_sec
# 1                 NaN              NaN   pale_cyanotic            less_3_sec
# 2              normal           normal       pale_pink            less_3_sec
# 3                cold           normal   dark_cyanotic            more_3_sec
# 4                 NaN              NaN   dark_cyanotic            more_3_sec
#
# ...

# %%
data['outcome'].unique()
# Out:
# array(['died', 'euthanized', 'lived'], dtype=object)

# %%
categorical_columns = data.columns[data.dtypes=='object']

# %%
categorical_columns
# Out:
# Index(['surgery', 'age', 'temp_of_extremities', 'peripheral_pulse',
#        'mucous_membrane', 'capillary_refill_time', 'pain', 'peristalsis',
#        'abdominal_distention', 'nasogastric_tube', 'nasogastric_reflux',
#        'rectal_exam_feces', 'abdomen', 'abdomo_appearance', 'outcome',
#        'surgical_lesion', 'cp_data'],
#       dtype='object')

# %%
features = data.drop(['outcome'], axis = 1)
target = data['outcome']

# %%
features = pd.get_dummies(features)

# %%
features
# Out:
#      hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0             530101         38.5   66.0              28.0
# 1             534817         39.2   88.0              20.0
# 2             530334         38.3   40.0              24.0
# 3            5290409         39.1  164.0              84.0
# 4             530255         37.3  104.0              35.0
# ..               ...          ...    ...               ...
# 294           533886          NaN  120.0              70.0
# 295           527702         37.2   72.0              24.0
# 296           529386         37.5   72.0              30.0
# 297           530612         36.5  100.0              24.0
# 298           534618         37.2   40.0              20.0
#
#      nasogastric_reflux_ph  packed_cell_volume  total_protein  abdomo_protein  \
# 0                      NaN                45.0            8.4             NaN
# 1                      NaN                50.0           85.0             2.0
# ...

# %%
features.columns
# Out:
# Index(['hospital_number', 'rectal_temp', 'pulse', 'respiratory_rate',
#        'nasogastric_reflux_ph', 'packed_cell_volume', 'total_protein',
#        'abdomo_protein', 'lesion_1', 'lesion_2', 'lesion_3', 'surgery_no',
#        'surgery_yes', 'age_adult', 'age_young', 'temp_of_extremities_cold',
#        'temp_of_extremities_cool', 'temp_of_extremities_normal',
#        'temp_of_extremities_warm', 'peripheral_pulse_absent',
#        'peripheral_pulse_increased', 'peripheral_pulse_normal',
#        'peripheral_pulse_reduced', 'mucous_membrane_bright_pink',
#        'mucous_membrane_bright_red', 'mucous_membrane_dark_cyanotic',
#        'mucous_membrane_normal_pink', 'mucous_membrane_pale_cyanotic',
#        'mucous_membrane_pale_pink', 'capillary_refill_time_3',
#        'capillary_refill_time_less_3_sec', 'capillary_refill_time_more_3_sec',
#        'pain_alert', 'pain_depressed', 'pain_extreme_pain', 'pain_mild_pain',
# ...

# %%
print(features.isna().sum())
# Out:
# hospital_number                      0
# rectal_temp                         60
# pulse                               24
# respiratory_rate                    58
# nasogastric_reflux_ph              246
#                                   ...
# abdomo_appearance_serosanguious      0
# surgical_lesion_no                   0
# surgical_lesion_yes                  0
# cp_data_no                           0
# cp_data_yes                          0
# Length: 67, dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
imp = SimpleImputer(missing_values=np.NaN, strategy='most_frequent')

# %%
features = imp.fit_transform(features)

# %%
pd.DataFrame(features).isna().any().any()
# Out:
# False

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
lbl_encoder=LabelEncoder()
target = lbl_encoder.fit_transform(target)

# %%
X_train,X_test,y_train,y_test = train_test_split(features,target)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (224, 67)
# (75, 67)
# (224,)
# (75,)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
my_dt_classifier = DecisionTreeClassifier()

# %%
my_dt_classifier.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
my_dt_predictions = my_dt_classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
accuracy_score(my_dt_predictions,y_test)
# Out:
# 0.6266666666666667

# %%
confusion_matrix(my_dt_predictions,y_test)
# Out:
# array([[13,  3, 10],
#        [ 2,  3,  6],
#        [ 6,  1, 31]])

# %%
print(classification_report(my_dt_predictions,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.50      0.55        26
#            1       0.43      0.27      0.33        11
#            2       0.66      0.82      0.73        38
#
#     accuracy                           0.63        75
#    macro avg       0.57      0.53      0.54        75
# weighted avg       0.61      0.63      0.61        75

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
my_rf_classifier = RandomForestClassifier(n_estimators=)

# %%
my_rf_classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
my_rf_preds = my_rf_classifier.predict(X_test)

# %%
accuracy_score(my_rf_preds,y_test)
# Out:
# 0.72

# %%
confusion_matrix(my_rf_preds,y_test)
# Out:
# array([[14,  1,  5],
#        [ 0,  2,  4],
#        [ 7,  4, 38]])

# %%
print(classification_report(my_rf_preds,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.70      0.68        20
#            1       0.29      0.33      0.31         6
#            2       0.81      0.78      0.79        49
#
#     accuracy                           0.72        75
#    macro avg       0.59      0.60      0.59        75
# weighted avg       0.73      0.72      0.72        75
